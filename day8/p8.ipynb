# %%
lines = [l.strip() for l in open("input.txt").readlines()]
exlines = [l.strip() for l in open("exampleinput.txt").readlines()]
import numpy as np

# %%
lines = [l.strip() for l in open("input.txt").readlines()]


route = lines[0] * 4000

routes = {}

lines = lines[2:] * 40
print(lines)
print(route)

counter=0

for i in lines:
  h = i.split('=')
  entry = h[0][0:3]
  #print(h[0])
  #print(h[1][1:])
  leftside = h[1][1:][1:4]
  #print(leftside)
  rightside = h[1][1:][6:9]
  #print(rightside)
  routes[entry] = [leftside,rightside]

print(routes)


currstr = "AAA"

for i in route:
  #print(i,currstr)
  counter += 1
  #print(routes[currstr])
  if i == 'L':
    currstr = routes[currstr][0]
  else:
    currstr = routes[currstr][1]
  #print(currstr)
  if currstr == 'ZZZ':
    break
print(counter)


  
print(routes)

# %%
lines = [l.strip() for l in open("input.txt").readlines()]


route = lines[0] 

routes = {}

lines = lines[2:]
print(lines)
print(route)

counter=0


Anodes = []

for i in lines:
  h = i.split('=')
  entry = h[0][0:3]
  #print(h[0])
  #print(h[1][1:])
  leftside = h[1][1:][1:4]
  #print(leftside)
  rightside = h[1][1:][6:9]
  #print(rightside)
  routes[entry] = [leftside,rightside]
  if entry[2] == 'A':
    Anodes.append([entry,leftside,rightside])

print(Anodes)
print(routes)

print(len(Anodes))

currstr = "AAA"

print(len(Anodes))


e = 0
while True:
  i = route[e]
  tempcounter = 0
  for j in Anodes:
    #print(j,i)
    if i == 'L':
      oldj = j[0]
      j[0] = j[1]
      j[1], j[2] = routes[j[0]][0], routes[j[0]][1] 
    else:
      oldj = j[0]
      j[0] = j[2]
      j[1], j[2] = routes[j[0]][0], routes[j[0]][1] 
    #print(j)
    if j[0][2] == 'Z':
      tempcounter += 1
      
  counter+= 1
  #print(tempcounter)
  if tempcounter == len(Anodes):
    print("finished")
    print(counter)
    break
  #print(i,currstr)
  #print(currstr)
  if currstr == 'ZZZ':
    break
  e = (e+1) % (len(route))
#print(counter)

print(counter)

  
#print(routes)
# Out:
# ['GLJ = (QQV, JTL)', 'JSJ = (DKN, GQN)', 'MGD = (BPL, LQC)', 'VSK = (SPH, DDH)', 'TSB = (MKP, TKX)', 'HPD = (GKG, XMX)', 'BLZ = (HGN, KRR)', 'BMQ = (JXC, HFC)', 'GDG = (BVJ, NBL)', 'LST = (PVJ, DPR)', 'QQQ = (RLV, SNJ)', 'TMV = (XGV, KCL)', 'NPZ = (JRD, NHL)', 'DDH = (NDR, XPN)', 'SFQ = (TKD, SQH)', 'RNK = (TJN, NFX)', 'FRS = (SCJ, FDV)', 'RST = (BSQ, MHQ)', 'DSM = (FRX, DMN)', 'GBN = (VBL, XRK)', 'GLH = (KNN, PKP)', 'JRD = (LDP, RNH)', 'SPV = (JNR, FRK)', 'PMD = (FXP, BKL)', 'MDV = (MGD, FHM)', 'MGG = (KMN, QPL)', 'FNX = (FKG, NLT)', 'FPH = (QXS, PBR)', 'DKP = (QFT, QQQ)', 'XVH = (PVP, GBJ)', 'SSP = (BHD, KRM)', 'JVR = (RHB, LDJ)', 'HCX = (RNK, LGT)', 'LRX = (SFN, GXD)', 'DXN = (NQX, KNL)', 'GNT = (GHV, DKG)', 'QVF = (NJN, FSN)', 'QHQ = (FXN, PNP)', 'CHX = (DHN, BQB)', 'GQD = (TLQ, XXG)', 'RMF = (RVF, KKR)', 'JHN = (NRG, RCC)', 'MBG = (XPV, MSB)', 'XJN = (SQT, XXJ)', 'JNR = (VTP, XSF)', 'NXD = (DKP, MKJ)', 'LSS = (KHS, BSV)', 'SQH = (BLH, VCG)', 'TLM = (DCG, BQL)', 'HTG = (TLF, KRB)
# ...

# %%
lines = [l.strip() for l in open("input.txt").readlines()]


route = lines[0] 

routes = {}

lines = lines[2:]
print(lines)
print(route)

counter=0


Anodes = []

for i in lines:
  h = i.split('=')
  entry = h[0][0:3]
  #print(h[0])
  #print(h[1][1:])
  leftside = h[1][1:][1:4]
  #print(leftside)
  rightside = h[1][1:][6:9]
  #print(rightside)
  routes[entry] = [leftside,rightside]
  if entry[2] == 'A':
    Anodes.append([entry,leftside,rightside])

print(Anodes)
print(routes)

print(len(Anodes))

currstr = "AAA"

print(len(Anodes))

print('hi', Anodes)

lcm = []

for node in Anodes:
  e = 0
  tempcounter = 0
  j = node
  while True:
    i = route[e]
    if i == 'L':
      oldj = j[0]
      j[0] = j[1]
      j[1], j[2] = routes[j[0]][0], routes[j[0]][1] 
    else:
      oldj = j[0]
      j[0] = j[2]
      j[1], j[2] = routes[j[0]][0], routes[j[0]][1] 
    #print(j)
    tempcounter += 1
    if j[0][2] == 'Z':
      lcm.append(tempcounter)
      break
    e = (e+1) % (len(route))

#print(counter)

print(counter)
print(lcm)
  
#print(routes)
# Out:
# ['GLJ = (QQV, JTL)', 'JSJ = (DKN, GQN)', 'MGD = (BPL, LQC)', 'VSK = (SPH, DDH)', 'TSB = (MKP, TKX)', 'HPD = (GKG, XMX)', 'BLZ = (HGN, KRR)', 'BMQ = (JXC, HFC)', 'GDG = (BVJ, NBL)', 'LST = (PVJ, DPR)', 'QQQ = (RLV, SNJ)', 'TMV = (XGV, KCL)', 'NPZ = (JRD, NHL)', 'DDH = (NDR, XPN)', 'SFQ = (TKD, SQH)', 'RNK = (TJN, NFX)', 'FRS = (SCJ, FDV)', 'RST = (BSQ, MHQ)', 'DSM = (FRX, DMN)', 'GBN = (VBL, XRK)', 'GLH = (KNN, PKP)', 'JRD = (LDP, RNH)', 'SPV = (JNR, FRK)', 'PMD = (FXP, BKL)', 'MDV = (MGD, FHM)', 'MGG = (KMN, QPL)', 'FNX = (FKG, NLT)', 'FPH = (QXS, PBR)', 'DKP = (QFT, QQQ)', 'XVH = (PVP, GBJ)', 'SSP = (BHD, KRM)', 'JVR = (RHB, LDJ)', 'HCX = (RNK, LGT)', 'LRX = (SFN, GXD)', 'DXN = (NQX, KNL)', 'GNT = (GHV, DKG)', 'QVF = (NJN, FSN)', 'QHQ = (FXN, PNP)', 'CHX = (DHN, BQB)', 'GQD = (TLQ, XXG)', 'RMF = (RVF, KKR)', 'JHN = (NRG, RCC)', 'MBG = (XPV, MSB)', 'XJN = (SQT, XXJ)', 'JNR = (VTP, XSF)', 'NXD = (DKP, MKJ)', 'LSS = (KHS, BSV)', 'SQH = (BLH, VCG)', 'TLM = (DCG, BQL)', 'HTG = (TLF, KRB)
# ...
